# %% [markdown]
# <a href="https://colab.research.google.com/github/Yujin726/0624/blob/main/07_16_yolov8_1_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 구글 드라이브 마운트 (처음 한 번만 실행)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

uploaded = files.upload()  # yolov8n.pt, yolov11n.pt 선택해서 업로드
# Out:
#      <input type="file" id="files-57dffb72-c4e1-412a-8a7a-a9c7cb74a79d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57dffb72-c4e1-412a-8a7a-a9c7cb74a79d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# drive  sample_data  yolo11n.pt	yolov8n.pt

# %%
# !cp yolo11n.pt /content/drive/MyDrive/yolo11n.pt

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/yolo11n.pt")

# %%
model = YOLO("/content/drive/MyDrive/yolov8n.pt")

# %%
from google.colab import files
uploaded = files.upload()
image_path = list(uploaded.keys())[0]

results = model(image_path)
results[0].show()
# Out:
#      <input type="file" id="files-12d49569-c1a1-42fa-9c53-17439d8cdb82" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12d49569-c1a1-42fa-9c53-17439d8cdb82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
